# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/thermal_enhancement_v2
# Out:
# /content/drive/MyDrive/thermal_enhancement_v2

# %%
# !pip install tensorboardX
# !pip install wandb
# !pip install git+https://github.com/aliutkus/torchinterp1d
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 19.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=d33cefbf5ad6d87dced185681e9b210403a7b6f3c5042c81711355c37bde8af2
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# ...
#   Cloning https://github.com/aliutkus/torchinterp1d to /tmp/pip-req-build-m8k8jxkf
#   Running command git clone --filter=blob:none --quiet https://github.com/aliutkus/torchinterp1d /tmp/pip-req-build-m8k8jxkf
# ...

# %%
# !python train_freiburg_vanilla.py --wandb --name_wandb rgb_thermal_1600_1800 --low_noise_ratio 1600 --high_noise_ratio 1800
# Out:
# ------------ Options -------------
# batchSize: 1
# batch_size_da: 4
# beta1: 0.9
# channels: 4
# checkpoints_dir: ./checkpoints
# chop: False
# crf: False
# debug: False
# exclude: None
# gpu_ids: [0]
# gt_wb: False
# high_noise_ratio: 1800
# include: None
# isTrain: True
# loss: l1
# low_noise_ratio: 1600
# lr: 0.0001
# max_dataset_size: None
# model_path: None
# nThreads: 8
# name: None
# name_wandb: rgb_thermal_1600_1800
# netG: unet
# no_log: False
# no_verbose: False
# noise: g+P
# notes: noise_on_fly_ratio_600_800
# num_epochs_da: 10
# num_workers: 8
# only_rgb: False
# resume: False
# resume_epoch: None
# seed: 2018
# serial_batches: False
# stage_eval: raw
# stage_in: raw
# stage_out: raw
# wandb: True
# wd: 0
# -------------- End ----------------
# wandb: Currently logged in as: jharaman400 (ramanjha). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.11
# ...

# %%
# !wandb sync /content/drive/MyDrive/thermal_enhancement_v2/wandb/offline-run-20230830_070217-3xqgdxtq
# Out:
# Usage: wandb sync [OPTIONS] [PATH]...
# Try 'wandb sync --help' for help.
#
# Error: Invalid value for '[PATH]...': Path '/content/drive/MyDrive/thermal_enhancement_v2/wandb/offline-run-20230830_070217-3xqgdxtq' does not exist.

# %%
import matplotlib.pyplot as plt
import imageio

# %%
image = imageio.imread("/content/I00001.jpg") # [H, W, 3]
image.shape
# Out:
# <ipython-input-13-349bb14e53ca>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread("/content/I00001.jpg") # [H, W, 3]
# (512, 640, 3)

# %%
image1 = imageio.imread("/content/I00000.jpg") # [H, W, 3]
image.shape
# Out:
# <ipython-input-14-8ed41ee06672>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image1 = imageio.imread("/content/I00000.jpg") # [H, W, 3]
# (512, 640, 3)

# %%
import matplotlib.pyplot as plt
import imageio

# %%
image2 = imageio.imread("/content/drive/MyDrive/thermal_enhancement_v2/set1/thermal_test_hr/I01215.jpg") # [H, W, 3]
# Out:
# <ipython-input-31-622339009e4e>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image2 = imageio.imread("/content/drive/MyDrive/thermal_enhancement_v2/set1/thermal_test_hr/I01215.jpg") # [H, W, 3]

# %%
image2.shape
# Out:
# (512, 640, 3)

# %%
image2[1]
# Out:
# array([[60, 58, 60],
#        [60, 58, 60],
#        [60, 58, 60],
#        ...,
#        [43, 41, 43],
#        [14, 12, 14],
#        [ 1,  0,  1]], dtype=uint8)

# %%
image2[:,:,0] == image2[:,:,2]
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
plt.imshow(image2[:,:,2])

# %%
plt.imshow(image2)
